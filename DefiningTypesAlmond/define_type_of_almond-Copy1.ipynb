# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
data = pd.read_csv(r'Almond.csv')
data
# Out:
#       Unnamed: 0  Length (major axis)  Width (minor axis)  Thickness (depth)  \
# 0              0                  NaN          227.940628         127.759132
# 1              1                  NaN          234.188126         128.199509
# 2              2                  NaN          229.418610         125.796547
# 3              3                  NaN          232.763153         125.918808
# 4              4                  NaN          230.150742         107.253448
# ...          ...                  ...                 ...                ...
# 2798        2798                  NaN          192.709366         122.356506
# 2799        2799                  NaN          186.254745         118.708961
# 2800        2800                  NaN          186.196182         119.147224
# 2801        2801                  NaN          188.660828         120.634438
# 2802        2802           269.356903          176.023636                NaN
#
#          Area   Perimeter  Roundness  Solidity  Compactness  Aspect Ratio  \
# 0     22619.0  643.813269        NaN  0.973384     1.458265           NaN
# 1     23038.0  680.984841        NaN  0.957304     1.601844           NaN
# 2     22386.5  646.943212        NaN  0.967270     1.487772           NaN
# 3     22578.5  661.227483        NaN  0.965512     1.540979           NaN
# 4     19068.0  624.842706        NaN  0.951450     1.629395           NaN
# ...       ...         ...        ...       ...          ...           ...
# 2798  18471.5  653.345233        NaN  0.931000     1.838965           NaN
# 2799  17213.5  581.688379        NaN  0.952706     1.564234           NaN
# 2800  17510.5  608.315795        NaN  0.948821     1.681705           NaN
# 2801  17941.0  630.759446        NaN  0.944810     1.764701           NaN
# 2802  36683.5  887.310743   0.643761  0.947380     1.707933      1.530231
#
#       Eccentricity    Extent  Convex hull(convex area)    Type
# 0              NaN  0.681193                   23237.5   MAMRA
# 1              NaN  0.656353                   24065.5   MAMRA
# 2              NaN  0.683620                   23144.0   MAMRA
# 3              NaN  0.685360                   23385.0   MAMRA
# 4              NaN  0.714800                   20041.0   MAMRA
# ...            ...       ...                       ...     ...
# 2798           NaN  0.725739                   19840.5  SANORA
# 2799           NaN  0.714016                   18068.0  SANORA
# 2800           NaN  0.718999                   18455.0  SANORA
# 2801           NaN  0.738191                   18989.0  SANORA
# 2802       0.75693  0.722429                   38721.0  SANORA
#
# [2803 rows x 14 columns]

# %%
data.describe(include="all")
# Out:
#          Unnamed: 0  Length (major axis)  Width (minor axis)  \
# count   2803.000000          1946.000000         1861.000000
# unique          NaN                  NaN                 NaN
# top             NaN                  NaN                 NaN
# freq            NaN                  NaN                 NaN
# mean    1401.000000           290.609274          171.025915
# std      809.300727            62.719433           29.916529
# min        0.000000           151.335266           88.050529
# 25%      700.500000           245.966293          149.453659
# 50%     1401.000000           279.879883          170.168365
# 75%     2101.500000           330.508575          190.640427
# max     2802.000000           515.352478          258.569794
#
#         Thickness (depth)          Area    Perimeter    Roundness  \
# count         1799.000000   2803.000000  2803.000000  1946.000000
# unique                NaN           NaN          NaN          NaN
# top                   NaN           NaN          NaN          NaN
# freq                  NaN           NaN          NaN          NaN
# mean           109.705378  26511.117374   743.863770     0.470466
# std             18.940597  13782.561344   230.632076     0.118673
# min             59.494278   6037.000000   311.563489     0.173748
# 25%             97.091682  16211.500000   571.730009     0.384810
# 50%            110.280136  23440.500000   707.487369     0.472718
# 75%            121.392773  33451.000000   878.896530     0.577553
# max            181.845200  89282.000000  1864.947387     0.697293
#
#            Solidity  Compactness  Aspect Ratio  Eccentricity       Extent  \
# count   2803.000000  2803.000000   1004.000000   1004.000000  2803.000000
# unique          NaN          NaN           NaN           NaN          NaN
# top             NaN          NaN           NaN           NaN          NaN
# freq            NaN          NaN           NaN           NaN          NaN
# mean       0.955828     1.825233      1.753216      0.813114     0.724587
# std        0.039596     0.794058      0.206616      0.041312     0.047474
# min        0.718772     1.164469      1.400082      0.699897     0.454538
# 25%        0.944579     1.357398      1.612490      0.784476     0.701673
# 50%        0.970422     1.576412      1.705716      0.810120     0.733720
# 75%        0.981484     1.965953      1.833339      0.838141     0.757551
# max        0.992889     9.660057      2.731251      0.930563     0.845813
#
#         Convex hull(convex area)    Type
# count                2803.000000    2803
# unique                       NaN       3
# top                          NaN  SANORA
# freq                         NaN     943
# mean                27696.218159     NaN
# std                 14237.347610     NaN
# min                  6355.000000     NaN
# 25%                 17088.500000     NaN
# 50%                 24589.000000     NaN
# 75%                 34863.250000     NaN
# max                 90642.500000     NaN

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                     0
# Length (major axis)          857
# Width (minor axis)           942
# Thickness (depth)           1004
# Area                           0
# Perimeter                      0
# Roundness                    857
# Solidity                       0
# Compactness                    0
# Aspect Ratio                1799
# Eccentricity                1799
# Extent                         0
# Convex hull(convex area)       0
# Type                           0
# dtype: int64

# %%
for i in data.drop(["Type"], axis=1):
    data[i] = data[i].fillna(data[i].mean())

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                  0
# Length (major axis)         0
# Width (minor axis)          0
# Thickness (depth)           0
# Area                        0
# Perimeter                   0
# Roundness                   0
# Solidity                    0
# Compactness                 0
# Aspect Ratio                0
# Eccentricity                0
# Extent                      0
# Convex hull(convex area)    0
# Type                        0
# dtype: int64
